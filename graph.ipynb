# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("data/august2019.tsv", sep="\t")
df.head()
# Out:
#    S.N                 LOCATION           SUPPLY CHAIN           USER  \
# 0    1              MARDI KHOLA          Spring Source  Mahesh Sigdel
# 1    2              BHOTE KHOLA          Spring Source        Sanjita
# 2    3                 KALIMUDA          Spring Source         Ksitiz
# 3    4              BINDABASINI         Reservoir Tank          Shova
# 4    5  AMLABISAUNI (BEFORE CL)  Water Treatment Plant          Shova
#
#            COORDINATES  IMAGE    CREATED AT DATA TAKEN AT  TEMP  PH VALUE  \
# 0     28.2935 ,83.9317    NaN  Aug 30, 2019  Aug 30, 2019  26.8      8.28
# 1     28.2878 ,83.9539    NaN  Aug 27, 2019  Aug 27, 2019  26.8      8.38
# 2  28.278389,83.984757    NaN  Aug 27, 2019  Aug 27, 2019  26.8      8.37
# 3     28.2390 ,83.9828    NaN  Aug 14, 2019  Aug 14, 2019  25.4      6.95
# 4     28.2644 ,83.9745    NaN  Aug 14, 2019  Aug 14, 2019  26.9      7.34
#
#    EC VALUE  TURBIDITY (NTU)  FRC ECOLI PRESENCE  ECOLI NO  OTHER  \
# 0       125                5  0.1        PRESENT        64    NaN
# 1        55                5  0.1         ABSENT         0    NaN
# 2       275                5  0.1         ABSENT         0    NaN
# 3       120                5  0.1        PRESENT        12    NaN
# 4      1030                5  0.1        PRESENT         5    NaN
#
#                                   DETAILS
# 0  least count of transparency tube was 5
# 1  least count of transparency tube was 5
# 2  least count of transparency tube was 5
# 3  least count of transparency tube was 5
# 4  least count of transparency tube was 5

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1, sharex=True, figsize=(16,16), constrained_layout=True)
fig.suptitle('August 2019\n', fontsize=16)

ax1.plot(df['LOCATION'], df['TURBIDITY (NTU)'], marker='.', color='r')
ax1.set_title('Turbidity')

ax2.plot(df['LOCATION'], df['PH VALUE'], marker='.', color='b')
ax2.set_title('Ph Value')


ax3.plot(df['LOCATION'], df['EC VALUE'], marker='.', color='g')
ax3.set_title('Electrical Conductivity')

ax4.plot(df['LOCATION'], df['ECOLI NO'],  marker='.', color='c')
ax4.set_title('Ecoli Count')
ax4.tick_params(labelrotation=90)
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

plt.show()

# %%
corr = df[[ 'PH VALUE', 'EC VALUE', 'ECOLI NO']]
corr.corr(method='pearson') # {‘pearson’, ‘kendall’, ‘spearman’}
# Out:
#           PH VALUE  EC VALUE  ECOLI NO
# PH VALUE  1.000000 -0.309938 -0.012875
# EC VALUE -0.309938  1.000000 -0.183215
# ECOLI NO -0.012875 -0.183215  1.000000

# %%
fig.savefig('exports/august2019.png', facecolor=fig.get_facecolor(), edgecolor=None)
